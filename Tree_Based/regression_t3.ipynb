# %% [markdown]
# # Package

# %%
# PyTorch package and submodules
import torch
import torch.nn as nn
from torch.optim import SGD #gradient descent optimizer

# NumPy for math operations, and Pandas for processing tabular data.
import numpy as np
import pandas as pd

# Plotly plotting package
import plotly.graph_objects as go
import plotly.express as px

# Import matplotlib.pyplot to visualize tree models
import matplotlib.pyplot as plt

# Use imbalanced learn package
from imblearn.over_sampling import SMOTE

from genetic_selection import GeneticSelectionCV

from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics
from sklearn.metrics import roc_curve, auc, precision_recall_curve
from sklearn.metrics import f1_score, roc_auc_score, average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef, precision_score, recall_score

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import StratifiedKFold, train_test_split as tts, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
import lightgbm as lgb
import seaborn as sns
from sklearn.feature_selection import SequentialFeatureSelector as SFS

# %%
def predict_evaluation(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    result={'r2':r2,
            'rmse':rmse,
            'mse':mse,
            'mae':mae}
    return result

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv("/Users/Siqi/Desktop/SPH6004/Group/3Step_1Line.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  vent_duration   stay_id  calcium_48  creatinine_48  glucose_48  \
# 0           0       2.000000  37607624         9.1            0.6       145.0
# 1           1       4.000000  30515259         8.5            2.6       109.0
# 2           2      16.000000  33572547         8.2            1.4       100.0
# 3           3      15.000000  34776632         9.5            0.7       143.0
# 4           4     104.133333  36606626         8.7            0.7       107.0
#
#    sodium_48  chloride_48  hemoglobin_48  wbc_48  ...  glucose+24  sodium+24  \
# 0      145.0        103.0            7.6     1.7  ...        79.5      145.0
# 1      134.0         94.0            7.1     2.2  ...       198.0      140.0
# 2      139.0        111.0            8.5     0.1  ...       142.0      134.0
# 3      131.0         88.0            7.7     9.6  ...       117.5      148.0
# 4      143.0        113.0            8.1     2.8  ...        85.0      141.0
#
#    chloride+24  hemoglobin+24  wbc+24  alt+24  ast+24  alp+24  \
# 0        104.0           7.15    1.50    21.0    21.0    72.0
# 1        104.0           7.90    7.80   168.0   330.5    39.0
# 2        106.0           9.00    0.10    13.0    25.0    77.0
# 3        106.0           8.75   12.95    75.0   275.5   171.0
# 4        109.0           9.40    3.70    17.0    20.0    78.0
#
#    bilirubin_total+24  pt+24
# 0                0.50  12.20
# 1                3.65  18.85
# 2                1.20  14.30
# 3               33.20  37.60
# 4                1.40  12.40
#
# [5 rows x 39 columns]

# %%
df = df.drop(['Unnamed: 0','stay_id'], axis=1)

# %%
df.head()
# Out:
#    vent_duration  calcium_48  creatinine_48  glucose_48  sodium_48  \
# 0       2.000000         9.1            0.6       145.0      145.0
# 1       4.000000         8.5            2.6       109.0      134.0
# 2      16.000000         8.2            1.4       100.0      139.0
# 3      15.000000         9.5            0.7       143.0      131.0
# 4     104.133333         8.7            0.7       107.0      143.0
#
#    chloride_48  hemoglobin_48  wbc_48  alt_48  ast_48  ...  glucose+24  \
# 0        103.0            7.6     1.7    19.0    25.0  ...        79.5
# 1         94.0            7.1     2.2    34.0    39.0  ...       198.0
# 2        111.0            8.5     0.1    13.0    18.0  ...       142.0
# 3         88.0            7.7     9.6    69.0   263.0  ...       117.5
# 4        113.0            8.1     2.8    17.0    20.0  ...        85.0
#
#    sodium+24  chloride+24  hemoglobin+24  wbc+24  alt+24  ast+24  alp+24  \
# 0      145.0        104.0           7.15    1.50    21.0    21.0    72.0
# 1      140.0        104.0           7.90    7.80   168.0   330.5    39.0
# 2      134.0        106.0           9.00    0.10    13.0    25.0    77.0
# 3      148.0        106.0           8.75   12.95    75.0   275.5   171.0
# 4      141.0        109.0           9.40    3.70    17.0    20.0    78.0
#
#    bilirubin_total+24  pt+24
# 0                0.50  12.20
# 1                3.65  18.85
# 2                1.20  14.30
# 3               33.20  37.60
# 4                1.40  12.40
#
# [5 rows x 37 columns]

# %%
feature_columns = df.columns[~df.columns.isin(['vent_duration'])]
target_column = df['vent_duration']

for i in feature_columns:
  df[i] = pd.to_numeric(df[i])

#df.replace({'outcome': {'False': 0, 'True': 1}})
#df['gender'].replace(to_replace = 'M', value = 1, inplace = True)

df.head()
#df.info()
#df.shape
# Out:
#    vent_duration  calcium_48  creatinine_48  glucose_48  sodium_48  \
# 0       2.000000         9.1            0.6       145.0      145.0
# 1       4.000000         8.5            2.6       109.0      134.0
# 2      16.000000         8.2            1.4       100.0      139.0
# 3      15.000000         9.5            0.7       143.0      131.0
# 4     104.133333         8.7            0.7       107.0      143.0
#
#    chloride_48  hemoglobin_48  wbc_48  alt_48  ast_48  ...  glucose+24  \
# 0        103.0            7.6     1.7    19.0    25.0  ...        79.5
# 1         94.0            7.1     2.2    34.0    39.0  ...       198.0
# 2        111.0            8.5     0.1    13.0    18.0  ...       142.0
# 3         88.0            7.7     9.6    69.0   263.0  ...       117.5
# 4        113.0            8.1     2.8    17.0    20.0  ...        85.0
#
#    sodium+24  chloride+24  hemoglobin+24  wbc+24  alt+24  ast+24  alp+24  \
# 0      145.0        104.0           7.15    1.50    21.0    21.0    72.0
# 1      140.0        104.0           7.90    7.80   168.0   330.5    39.0
# 2      134.0        106.0           9.00    0.10    13.0    25.0    77.0
# 3      148.0        106.0           8.75   12.95    75.0   275.5   171.0
# 4      141.0        109.0           9.40    3.70    17.0    20.0    78.0
#
#    bilirubin_total+24  pt+24
# 0                0.50  12.20
# 1                3.65  18.85
# 2                1.20  14.30
# 3               33.20  37.60
# 4                1.40  12.40
#
# [5 rows x 37 columns]

# %% [markdown]
# # Feature Selection & TTS

# %%
# corr_matrix=df_norm.corr().abs()
# upper_triangle=corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(np.bool))
# to_drop=[column for column in upper_triangle.columns if any(upper_triangle[column]>0.80)]
# data_select1=data_norm.drop(to_drop, axis=1)


# selector=VarianceThreshold(0)
# selector.fit(data_select1)
# selected_features=selector.get_support(indices=True)
# selected_column_names=data_select1.columns[selected_features].tolist()
# data_select2=data_select1[selected_column_names]

# %%
X_raw = df.loc[:, ~df.columns.isin(['vent_duration', 'stay_id'])]
Y_raw = df['vent_duration']  
##df['vent_hours'].map(target_map)


# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# Y_raw = le.fit_transform(Y_raw)

# # Check data balance 
# print("0-12 hours:", len(Y_raw[Y_raw=='0-12 hour']))
# print("12-24 hrs:", len(Y_raw[Y_raw == '12-24 hrs']))
# print(">24 hrs:", len(Y_raw[Y_raw == '>24 hrs']))


vent_duration_counts = df['vent_duration'].value_counts()
print(vent_duration_counts)
# Out:
# 13.000000    45
# 7.000000     40
# 5.000000     36
# 10.000000    34
# 6.000000     33
#              ..
# 7.816667      1
# 5.116667      1
# 9.133333      1
# 8.366667      1
# 18.483333     1
# Name: vent_duration, Length: 859, dtype: int64

# %%
Xtrain, Xtest, Ytrain, Ytest = tts(X_raw, Y_raw , test_size=0.2, random_state=1)

# %% [markdown]
# # XGboost

# %%
dtrain = xgb.DMatrix(Xtrain, label=Ytrain)
dtest = xgb.DMatrix(Xtest, label=Ytest)

# %%
## Baseline
xgb_model = xgb.XGBRegressor(objective ='reg:squarederror', n_estimators=100)
xgb_model.fit(Xtrain, Ytrain)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
predy = xgb_model.predict(Xtest)

# %%
rmse = np.sqrt(mean_squared_error(Ytest, predy))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 63.787171

# %%
result=predict_evaluation(Ytest, predy)
result
# Out:
# {'r2': -0.20850581399412715,
#  'rmse': 63.78717141446835,
#  'mse': 4068.803237058768,
#  'mae': 39.78427433616214}

# %%
# GridSearch

xgb_model = xgb.XGBRegressor()

# Define hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'objective': ['reg:squarederror', 'reg:logistic', 'reg:gamma']
}

# Create grid search object
grid_search = GridSearchCV(xgb_model, param_grid, cv=5)
grid_search.fit(Xtrain, Ytrain)

print(f'Best hyperparameters: {grid_search.best_params_}')
# Out:
# Best hyperparameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'objective': 'reg:gamma'}
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 180 fits failed out of a total of 540.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:45] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:46] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:48] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:52] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:53] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:55] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:14:58] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:00] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:02] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:03] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:04] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:07] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:09] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:10] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:13] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:15] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:16] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:17] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:19] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
# ...
# xgboost.core.XGBoostError: [04:15:33] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:34] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:35] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:38] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:39] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:41] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/sklearn.py", line 972, in fit
#     callbacks=callbacks,
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 575, in inner_f
#     return f(**kwargs)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 1780, in update
#     dtrain.handle))
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/xgboost/core.py", line 246, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [04:15:44] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/objective/regression_obj.cu:138: label must be in [0,1] for logistic regression
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001799cd705 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000179b111f4 xgboost::obj::RegLossObj<xgboost::obj::LogisticRegression>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 820
#   [bt] (2) 3   libxgboost.dylib                    0x0000000179aa16b5 xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 581
#   [bt] (3) 4   libxgboost.dylib                    0x00000001799d154a XGBoosterUpdateOneIter + 138
#   [bt] (4) 5   _ctypes.cpython-37m-darwin.so       0x000000010a7bd157 ffi_call_unix64 + 79
#   [bt] (5) 6   ???                                 0x000000030530d6c0 0x0 + 12971988672
#
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [-0.17691365         nan -0.46954247 -0.07618239         nan -0.45711142
#  -0.03941004         nan -0.40873656 -0.18189349         nan -0.46954247
#  -0.0865791          nan -0.45714041 -0.06228343         nan -0.40918107
#  -0.1822176          nan -0.46954247 -0.08030582         nan -0.45714156
#  -0.05943815         nan -0.40958723 -0.03669327         nan -0.366794
#  -0.04640035         nan -0.07097938 -0.06230593         nan -0.02414169
#  -0.07019595         nan -0.36824456 -0.09976092         nan -0.09310288
#  -0.13872477         nan -0.0528191  -0.09626328         nan -0.36994212
#  -0.13021801         nan -0.12664865 -0.15921612         nan -0.10146215
#  -0.04713275         nan -0.0688083  -0.05553339         nan -0.02516626
#  -0.09553623         nan -0.05650619 -0.08813089         nan -0.09006968
#  -0.11738022         nan -0.05486309 -0.16652358         nan -0.0943799
#  -0.14050579         nan -0.12524902 -0.16522875         nan -0.08786825
#  -0.18912821         nan -0.10494542 -0.07976921         nan -0.03546525
#  -0.14190871         nan -0.06096457 -0.18383814         nan -0.08843622
#  -0.13728958         nan -0.06594927 -0.19501766         nan -0.10344163
#  -0.21767163         nan -0.1182474  -0.19597877         nan -0.10640992
#  -0.22262087         nan -0.12622553 -0.22520133         nan -0.1290408 ]
#   category=UserWarning,

# %%
print(f'Best hyperparameters: {grid_search.best_params_}')
# Out:
# Best hyperparameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'objective': 'reg:gamma'}

# %%
xgb_model_2 = xgb.XGBRegressor(objective ='reg:squarederror', n_estimators=200, max_depth=3, learning_rate=0.01)
xgb_model_2.fit(Xtrain, Ytrain)
pred_y = xgb_model_2.predict(Xtest)

# %%
result=predict_evaluation(Ytest, pred_y)
result
# Out:
# {'r2': -0.009561643078361381,
#  'rmse': 58.30091798020457,
#  'mse': 3398.99703733454,
#  'mae': 33.21179032831609}

# %% [markdown]
# # Lightgbm

# %%
import lightgbm as lgb

# %%
#Baseline
model = lgb.LGBMRegressor()
model.fit(Xtrain, Ytrain)
# Out:
# LGBMRegressor()

# %%
y1 = model.predict(Xtest)
result=predict_evaluation(Ytest, y1)
result
# Out:
# {'r2': -0.08035981928746239,
#  'rmse': 60.3105354017002,
#  'mse': 3637.360680439733,
#  'mae': 38.076518221573906}

# %%
lgb_1 = lgb.LGBMRegressor()
param_grid = {
    'learning_rate': [0.01, 0.1,0.5, 1],
    'n_estimators': [20, 40,100],
    'num_leaves': [10, 20, 50, 100]
}

gridsearch = GridSearchCV(lgb_1, param_grid)
gridsearch.fit(Xtrain, Ytrain)
print(gridsearch.best_params_)
# Out:
# {'learning_rate': 0.01, 'n_estimators': 40, 'num_leaves': 10}

# %%
# create the LGBMClassifier object
best_estimator = lgb.LGBMRegressor(learning_rate=0.01, n_estimators=40, num_leaves = 10)

best_estimator.fit(Xtrain, Ytrain)
y2 = best_estimator.predict(Xtest)
result=predict_evaluation(Ytest, y2)
result
# Out:
# {'r2': 0.0070110197359329884,
#  'rmse': 57.82041262198684,
#  'mse': 3343.2001157768154,
#  'mae': 35.61809528374974}

# %% [markdown]
# # RandomForest

# %%
rf_model = RandomForestRegressor()

param_grid = {
    'n_estimators': [50, 100, 150, 200],
    'max_features': ['auto', 'sqrt'],
    'max_depth': [3, 5, 10, 15, None],
    'min_samples_split': [2,4,6,8,10],
    'max_features': ['auto', 'sqrt'],
    'min_samples_leaf': [1, 4, 8, 10],
}

# Perform grid search using 5-fold cross validation
rf_grid_search = GridSearchCV(rf_model, param_grid=param_grid, cv=5, verbose=3, n_jobs=-1)
rf_grid_search.fit(Xtrain, Ytrain)

print("Best parameters:", rf_grid_search.best_params_)
print("Best score:", rf_grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 800 candidates, totalling 4000 fits
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.006 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.117 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.004 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=-0.007 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.003 total time=   0.4s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.014 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.004 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.003 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=-0.086 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.004 total time=   0.6s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.007 total time=   0.9s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-0.006 total time=   0.9s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.004 total time=   1.0s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-0.147 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.009 total time=   0.9s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=50;, score=0.014 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=50;, score=-0.005 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.014 total time=   1.1s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=50;, score=-0.018 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=50;, score=-0.176 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=50;, score=0.002 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.009 total time=   1.1s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.004 total time=   1.2s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=-0.016 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=-0.117 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.007 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.010 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=-0.128 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=-0.002 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.007 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=-0.006 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=-0.172 total time=   0.7s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.005 total time=   0.7s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=-0.010 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.009 total time=   0.9s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=0.002 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-0.008 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.009 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=-0.000 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=-0.008 total time=   1.0s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=-0.265 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=50;, score=0.004 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=-0.195 total time=   1.1s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-0.011 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-0.001 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.007 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.013 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=-0.174 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.006 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=-0.013 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.010 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=-0.006 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=-0.149 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.004 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=-0.016 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-0.010 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-0.013 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=0.005 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.011 total time=   1.1s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=-0.005 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=0.006 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=50;, score=-0.207 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=-0.187 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=0.011 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-0.004 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-0.003 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.006 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=0.004 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=100;, score=-0.220 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=150;, score=-0.005 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=150;, score=0.008 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=150;, score=-0.177 total time=   0.9s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=150;, score=-0.004 total time=   0.9s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=150;, score=0.005 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.009 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.011 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.006 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200;, score=0.006 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200;, score=-0.012 total time=   1.1s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200;, score=-0.001 total time=   1.2s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=-0.265 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.000 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200;, score=-0.189 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.007 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=8, n_estimators=200;, score=0.006 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.012 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.006 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.004 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=-0.195 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.001 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.010 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=-0.010 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=-0.184 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=150;, score=0.007 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.012 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.015 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.011 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=-0.079 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.004 total time=   1.1s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.006 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.009 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.003 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=-0.174 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.007 total time=   1.1s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.007 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.012 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=-0.060 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.009 total time=   0.6s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.002 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.014 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.021 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=-0.010 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=-0.071 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.004 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.004 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.013 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.012 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=-0.014 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.009 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.024 total time=   1.1s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=-0.068 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=50;, score=0.008 total time=   0.2s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=-0.068 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.012 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.016 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=-0.015 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=-0.077 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.009 total time=   1.2s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.004 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.010 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.020 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=-0.008 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=-0.084 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.005 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=50;, score=0.012 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=50;, score=0.006 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=50;, score=-0.016 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.012 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.014 total time=   1.1s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=-0.010 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=50;, score=-0.072 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.005 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.007 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.015 total time=   0.6s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=-0.005 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=-0.081 total time=   1.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=-0.066 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.009 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.009 total time=   0.9s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.009 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=-0.006 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=-0.066 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.004 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.002 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.003 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.013 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.018 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=-0.017 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=-0.006 total time=   1.0s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=-0.100 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=50;, score=0.007 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=-0.077 total time=   1.1s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.009 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=-0.013 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.022 total time=   0.6s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=-0.070 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.007 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.008 total time=   1.1s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=150;, score=0.012 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=150;, score=0.018 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=150;, score=-0.004 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=150;, score=-0.054 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=150;, score=0.009 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.004 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.017 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=0.010 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.002 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=0.014 total time=   1.1s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=-0.015 total time=   1.0s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.081 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=-0.000 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=-0.082 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.004 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.017 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.002 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=0.002 total time=   1.0s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.007 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=-0.061 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.004 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.017 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=-0.011 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=-0.055 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=150;, score=0.007 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.010 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.015 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.009 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.010 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.016 total time=   1.0s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=-0.041 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=50;, score=0.012 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.010 total time=   1.1s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=-0.056 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.008 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.013 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.008 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.008 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=-0.033 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100;, score=0.011 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=150;, score=0.013 total time=   0.7s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=150;, score=-0.011 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=150;, score=0.016 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=150;, score=0.010 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=150;, score=-0.036 total time=   0.9s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.010 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.019 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=0.009 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=-0.013 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.016 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=0.015 total time=   1.1s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=-0.031 total time=   0.3s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=50;, score=0.009 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=-0.032 total time=   1.1s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.009 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=200;, score=0.010 total time=   1.0s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.020 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.020 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=-0.026 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=-0.022 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=150;, score=0.017 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=150;, score=0.014 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=150;, score=0.010 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=150;, score=-0.046 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=150;, score=-0.009 total time=   0.9s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=50;, score=0.001 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=50;, score=0.011 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=0.014 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=0.011 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=50;, score=-0.014 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=-0.019 total time=   1.2s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=50;, score=-0.029 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=50;, score=0.020 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=-0.032 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=0.007 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=0.012 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=0.014 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=-0.012 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=-0.024 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=0.011 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=150;, score=0.013 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=150;, score=0.011 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=150;, score=-0.027 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=150;, score=0.008 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=150;, score=-0.007 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.015 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.010 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=-0.024 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=0.013 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=0.013 total time=   1.0s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=-0.038 total time=   0.2s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=50;, score=0.010 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=-0.009 total time=   1.1s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=-0.042 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.014 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.011 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=-0.017 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=0.010 total time=   1.1s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=-0.037 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.007 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=150;, score=0.011 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=150;, score=0.016 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=150;, score=-0.018 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=150;, score=-0.034 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=150;, score=0.010 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=0.008 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=0.011 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.010 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=0.010 total time=   1.1s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=-0.038 total time=   0.2s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=-0.015 total time=   1.1s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=0.017 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=50;, score=0.011 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=-0.037 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=0.014 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=0.016 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=0.020 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.024 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=-0.032 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=0.013 total time=   0.6s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=0.007 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=0.016 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=-0.013 total time=   0.7s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=-0.028 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=0.012 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.015 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=-0.014 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.014 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=0.015 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=0.012 total time=   1.1s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=-0.033 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.013 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.012 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.026 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=0.011 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=0.019 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=0.012 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=-0.012 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=-0.028 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=0.009 total time=   0.5s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=0.009 total time=   0.7s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=0.017 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=-0.012 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=-0.013 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=0.015 total time=   0.9s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.020 total time=   0.2s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.006 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=-0.018 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=0.011 total time=   1.1s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=-0.018 total time=   0.9s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=-0.027 total time=   0.2s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=0.014 total time=   1.1s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.011 total time=   0.4s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=-0.018 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.012 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=-0.014 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.019 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=-0.022 total time=   0.4s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.012 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=0.015 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=0.013 total time=   0.8s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=0.018 total time=   0.8s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=-0.032 total time=   0.8s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=-0.014 total time=   0.8s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=0.013 total time=   0.8s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=0.007 total time=   0.3s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.012 total time=   1.0s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=0.014 total time=   0.3s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=-0.030 total time=   0.3s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.018 total time=   1.0s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=-0.011 total time=   1.0s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=0.016 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=-0.022 total time=   0.3s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=-0.032 total time=   1.0s
# [CV 1/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=0.013 total time=   0.5s
# [CV 3/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=-0.016 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=0.010 total time=   0.5s
# [CV 4/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=-0.026 total time=   0.5s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.014 total time=   1.0s
# [CV 5/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=0.013 total time=   0.5s
# [CV 2/5] END max_depth=3, max_features=auto, min_samples_leaf=10, min_samples_split=6, n_estimators=150;, score=0.016 total time=   0.8s
# ...
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=0.005 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=-0.017 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100;, score=0.017 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=-0.032 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=0.019 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=-0.016 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=150;, score=0.021 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=-0.010 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.002 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=-0.031 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=0.002 total time=   0.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=0.011 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=-0.014 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.023 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50;, score=0.018 total time=   0.2s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=-0.030 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=0.000 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200;, score=0.020 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=0.022 total time=   0.3s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=-0.022 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=-0.013 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=100;, score=0.023 total time=   0.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=0.004 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=-0.026 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=0.015 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=-0.009 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=150;, score=0.026 total time=   0.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=-0.012 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.012 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=-0.028 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=0.002 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=-0.023 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=-0.022 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=0.012 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=50;, score=0.018 total time=   0.2s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=0.015 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=200;, score=-0.020 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.016 total time=   0.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=-0.005 total time=   0.3s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=-0.028 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=0.015 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=100;, score=-0.018 total time=   0.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=-0.002 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=0.009 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=-0.038 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=0.002 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=150;, score=0.029 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=-0.005 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=0.018 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=-0.025 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=-0.002 total time=   0.9s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=-0.028 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.013 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=0.014 total time=   0.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=50;, score=-0.019 total time=   0.2s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=-0.012 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=-0.010 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=-0.030 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=-0.013 total time=   0.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=0.003 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=4, n_estimators=200;, score=0.021 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=100;, score=0.025 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=150;, score=0.009 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=150;, score=0.017 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=150;, score=-0.029 total time=   0.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=150;, score=-0.011 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=150;, score=0.017 total time=   0.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=50;, score=-0.009 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=50;, score=0.007 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=200;, score=-0.004 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=50;, score=-0.010 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=200;, score=0.017 total time=   0.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=200;, score=-0.017 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=50;, score=0.019 total time=   0.2s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=50;, score=-0.011 total time=   0.2s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=200;, score=-0.016 total time=   0.8s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=100;, score=0.019 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=100;, score=-0.000 total time=   0.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=100;, score=-0.026 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=100;, score=-0.019 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=200;, score=0.019 total time=   0.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=100;, score=0.016 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=150;, score=-0.009 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=150;, score=0.010 total time=   0.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=150;, score=-0.025 total time=   0.6s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=150;, score=0.021 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=150;, score=-0.015 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=200;, score=0.015 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-0.009 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.026 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-0.030 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=200;, score=-0.007 total time=   0.8s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=-0.026 total time=   0.2s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.009 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=200;, score=-0.016 total time=   0.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=200;, score=-0.016 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.000 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=200;, score=0.016 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=-0.021 total time=   0.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.014 total time=   0.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=-0.012 total time=   0.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100;, score=0.029 total time=   0.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=0.003 total time=   0.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=-0.039 total time=   0.5s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=0.014 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=0.007 total time=   0.5s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=150;, score=-0.005 total time=   0.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-0.001 total time=   0.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-0.029 total time=   0.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.018 total time=   0.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=-0.005 total time=   0.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200;, score=0.014 total time=   0.5s
# Best parameters: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 100}
# Best score: 0.00498660648898237

# %%
print("Best parameters:", rf_grid_search.best_params_)
# Out:
# Best parameters: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 100}

# %%
# gridsearch = GridSearchCV(rf_model, param_grid)

# # fit the grid search
# gridsearch.fit(Xtrain, Ytrain)

# # print the best parameters
# print(gridsearch.best_params_)

# %%
best_rf_model = RandomForestRegressor(max_depth = 3, max_features = 'sqrt', min_samples_leaf = 8, min_samples_split = 8, n_estimators = 100)
best_rf_model.fit(Xtrain, Ytrain)


best_rf_model.fit(Xtrain, Ytrain)
y3 = best_rf_model.predict(Xtest)
result=predict_evaluation(Ytest, y3)
result
# Out:
# {'r2': 0.017112428108645883,
#  'rmse': 57.525565143380256,
#  'mse': 3309.1906450652855,
#  'mae': 35.197976222903165}

# %% [markdown]
# # Logistics Regression

# %%
lg = LogisticRegression()
param_grid = {
    'C': [0.1, 1, 10, 50, 100, 1000],
    'penalty': [ 'l2', 'none']
}

lg_model = GridSearchCV(lg, param_grid=param_grid , cv = 5)
lg_model.fit(Xtrain, Ytrain)

print("Best parameters:", rf_grid_search.best_params_)
print("Best score:", rf_grid_search.best_score_)
# Out:
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py", line 1516, in fit
#     check_classification_targets(y)
#   File "/Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/utils/multiclass.py", line 197, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/Siqi/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   category=UserWarning,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qy/w7ktgxnx5svft6xymt5d8k1w0000gq/T/ipykernel_77349/163874187.py in <module>
#       6
#       7 lg_model = GridSearchCV(lg, param_grid=param_grid , cv = 5)
# ----> 8 lg_model.fit(Xtrain, Ytrain)
#       9
#      10 print("Best parameters:", rf_grid_search.best_params_)
#
# ~/Library/Python/3.7/lib/python/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# ~/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
# -> 1516         check_classification_targets(y)
#    1517         self.classes_ = np.unique(y)
#    1518
#
# ~/Library/Python/3.7/lib/python/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
#     196     ]:
# --> 197         raise ValueError("Unknown label type: %r" % y_type)
#     198
#     199
#
# ValueError: Unknown label type: 'continuous'

# %%
# fit the grid search
lg_model.fit(Xtrain, Ytrain)
